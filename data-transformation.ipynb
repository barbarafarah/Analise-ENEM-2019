# %% [markdown]
# # Summarizing the data
# Because the data set is big, we will select only the columns that we intend to work

# %%
import pandas as pd
import zipfile
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_enem = pd.read_csv("data/MICRODADOS_ENEM_2019.csv", sep=';',encoding='ISO-8859-1')

# %%
df_enem.head()
# Out:
#    NU_INSCRICAO  NU_ANO  TP_FAIXA_ETARIA TP_SEXO  TP_ESTADO_CIVIL  \
# 0  190001595656    2019               13       M                1
# 1  190001421546    2019                8       M                1
# 2  190001133210    2019               13       F                1
# 3  190001199383    2019               10       F                1
# 4  190001237802    2019                7       F                1
#
#    TP_COR_RACA  TP_NACIONALIDADE  TP_ST_CONCLUSAO  TP_ANO_CONCLUIU  TP_ESCOLA  \
# 0            3                 1                1               11          1
# 1            1                 1                1                5          1
# 2            3                 1                1               13          1
# 3            1                 1                1                4          1
# 4            1                 1                1                4          1
#
#    ...  Q016  Q017  Q018 Q019  Q020 Q021  Q022  Q023  Q024  Q025
# ...

# %%
#visualize all the columns
df_enem.columns.values
# Out:
# array(['NU_INSCRICAO', 'NU_ANO', 'TP_FAIXA_ETARIA', 'TP_SEXO',
#        'TP_ESTADO_CIVIL', 'TP_COR_RACA', 'TP_NACIONALIDADE',
#        'TP_ST_CONCLUSAO', 'TP_ANO_CONCLUIU', 'TP_ESCOLA', 'TP_ENSINO',
#        'IN_TREINEIRO', 'CO_MUNICIPIO_ESC', 'NO_MUNICIPIO_ESC',
#        'CO_UF_ESC', 'SG_UF_ESC', 'TP_DEPENDENCIA_ADM_ESC',
#        'TP_LOCALIZACAO_ESC', 'TP_SIT_FUNC_ESC', 'CO_MUNICIPIO_PROVA',
#        'NO_MUNICIPIO_PROVA', 'CO_UF_PROVA', 'SG_UF_PROVA',
#        'TP_PRESENCA_CN', 'TP_PRESENCA_CH', 'TP_PRESENCA_LC',
#        'TP_PRESENCA_MT', 'CO_PROVA_CN', 'CO_PROVA_CH', 'CO_PROVA_LC',
#        'CO_PROVA_MT', 'NU_NOTA_CN', 'NU_NOTA_CH', 'NU_NOTA_LC',
#        'NU_NOTA_MT', 'TX_RESPOSTAS_CN', 'TX_RESPOSTAS_CH',
#        'TX_RESPOSTAS_LC', 'TX_RESPOSTAS_MT', 'TP_LINGUA',
#        'TX_GABARITO_CN', 'TX_GABARITO_CH', 'TX_GABARITO_LC',
#        'TX_GABARITO_MT', 'TP_STATUS_REDACAO', 'NU_NOTA_COMP1',
#        'NU_NOTA_COMP2', 'NU_NOTA_COMP3', 'NU_NOTA_COMP4', 'NU_NOTA_COMP5',
# ...

# %% [markdown]
# Select relevant data, which are:
# - ‘geographic state of residence’
# - ‘age’
# - ‘gender’
# - ‘ethnicity’
# - ‘biology_grade’
# - ‘history_grade’
# - ‘portuguese_grade'
# - 'tech_grade'
# - ‘math_grade’
# - ‘school_type’
# - ‘mothers_schooling‘
# - ‘internet_access’
# - ‘household_income’
# - ‘presence_day1’
# - ‘presence_day1’

# %%
df_enem = df_enem[['NU_INSCRICAO','SG_UF_ESC','TP_FAIXA_ETARIA','TP_SEXO','TP_COR_RACA','NU_NOTA_CN', 'NU_NOTA_CH', 'NU_NOTA_LC',
       'NU_NOTA_MT','NU_NOTA_REDACAO','TP_ESCOLA','Q002','Q025','Q006', 'TP_PRESENCA_CH', 'TP_PRESENCA_MT']]
df_enem.head()
# Out:
#    NU_INSCRICAO SG_UF_ESC  TP_FAIXA_ETARIA TP_SEXO  TP_COR_RACA  NU_NOTA_CN  \
# 0  190001595656       NaN               13       M            3         NaN
# 1  190001421546       NaN                8       M            1         NaN
# 2  190001133210       NaN               13       F            3         NaN
# 3  190001199383       NaN               10       F            1       483.8
# 4  190001237802       NaN                7       F            1       513.6
#
#    NU_NOTA_CH  NU_NOTA_LC  NU_NOTA_MT  NU_NOTA_REDACAO  TP_ESCOLA Q002 Q025  \
# 0         NaN         NaN         NaN              NaN          1    B    B
# 1         NaN         NaN         NaN              NaN          1    E    B
# 2         NaN         NaN         NaN              NaN          1    E    B
# 3       503.6       537.3       392.0            460.0          1    E    B
# 4       575.5       570.7       677.0            860.0          1    E    B
#
#   Q006  TP_PRESENCA_CH  TP_PRESENCA_MT
# ...

# %% [markdown]
# Rename the columns

# %%
new_columns = ['id','geographic_state', 'age', 'gender', 'ethnicity', 'biology_grade', 'history_grade', 'portuguese_grade', 'tech_grade', 'math_grade',
               'school_type', 'mothers_schooling', 'internet_access', 'household_income', 'presence_day1', 'presence_day2']
df_enem.columns = new_columns
df_enem.to_csv('data/enem_summarized.csv')
